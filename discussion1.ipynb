# %% [markdown]
# <a href="https://colab.research.google.com/github/simonkaley/discussion1/blob/main/discussion1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive,files
drive.mount('/content/drive')
#uploaded = files.upload()

import numpy as np
import pandas as pd
import ipywidgets as widgets



hls_all_raw = pd.read_csv("/content/HSL_ALL.csv")

hls_slice = pd.DataFrame(hls_all_raw, columns =["Country","Indicator","Type of indicator","Time","Value"])
hls_ls = hls_slice.loc[hls_all_raw["Indicator"] == "Social support"]

print("\n===========================================================\n")
print("\nSocial support\n")
print("\n===========================================================\n")
hls_train = hls_ls.loc[hls_ls["Time"] == 2018]
hls_train = hls_train.loc[hls_ls["Type of indicator"] == "Average"]
print("\n===========================================================\n")
print("Total records:")
print(len(hls_train))

print("\n===========================================================\n")
print("Total Unique Countries:")
print(len(hls_train["Country"].unique()))

print("\n===========================================================\n")
print("Record:")
print(hls_train)

print("\n===========================================================\n")
print("\nGDP\n")
print("\n===========================================================\n")

weo_raw = pd.read_csv("/content/WEOOct2023all.xls", sep='\t', encoding='latin1')

weo_selected_measurement = weo_raw.loc[weo_raw['WEO Subject Code'].str.contains("PCPIPCH", na=False)]
weo_selected_measurement_2018 = pd.DataFrame(weo_selected_measurement, columns=['Country', '2018'])

merged_train_data = pd.merge(hls_train, weo_selected_measurement_2018, on="Country")
merged_train_data = merged_train_data.rename(columns={"Value": "Happiness Measurement", "2018": "Income Measurement"})
merged_train_data = pd.DataFrame(merged_train_data, columns=['Country','Happiness Measurement', 'Income Measurement'])

print(merged_train_data)

import matplotlib.pyplot as plt
import sklearn.linear_model



X = np.c_[merged_train_data["Income Measurement"]]
Y = np.c_[merged_train_data["Happiness Measurement"]]
x = X.tolist()
y = Y.tolist()

# plot data
out1 = widgets.Output()
with out1:
  plt.scatter(x, y)
  plt.xlabel('Income')
  plt.ylabel('Happiness')
  plt.title("Data Plot")
  plt.show()

# fit linear model
model = sklearn.linear_model.LinearRegression()
model.fit(X, Y)

# plot predictions
predict_x = [x for x in range(901)]
predict_x = [[x/100] for x in predict_x]
predict_y = model.predict(predict_x)

out2 = widgets.Output()
with out2:
  plt.scatter(predict_x, predict_y)
  plt.scatter(x, y)
  plt.xlabel('Income')
  plt.ylabel('Happiness')
  plt.title("Prediction Line")
  plt.show()

display(widgets.HBox([out1,out2]))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# ===========================================================
#
#
# Social support
#
#
# ===========================================================
#
#
# ===========================================================
#
# Total records:
# 40
#
# ===========================================================
#
# Total Unique Countries:
# 40
#
# ===========================================================
#
# Record:
#                Country       Indicator Type of indicator  Time      Value
# 116          Australia  Social support           Average  2018  93.282543
# 425            Austria  Social support           Average  2018  90.564838
# 772            Belgium  Social support           Average  2018  92.107227
# 1088            Canada  Social support           Average  2018  91.733480
# 1421           Czechia  Social support           Average  2018  91.690088
# 1758           Denmark  Social support           Average  2018  95.667063
# 2103           Finland  Social support           Average  2018  95.927086
# 2449            France  Social support           Average  2018  91.375633
# 2787           Germany  Social support           Average  2018  90.824276
# 3121            Greece  Social support           Average  2018  78.953671
# 3474           Hungary  Social support           Average  2018  93.508243
# 4088           Ireland  Social support           Average  2018  93.611828
# 4433             Italy  Social support           Average  2018  90.675076
# 4758             Japan  Social support           Average  2018  87.757218
# 5057             Korea  Social support           Average  2018  78.874962
# 5354        Luxembourg  Social support           Average  2018  88.977817
# 5636            Mexico  Social support           Average  2018  85.724824
# 5926       Netherlands  Social support           Average  2018  93.850994
# 6242       New Zealand  Social support           Average  2018  95.229375
# 6544            Norway  Social support           Average  2018  96.569664
# 6874            Poland  Social support           Average  2018  83.764614
# 7223          Portugal  Social support           Average  2018  88.469596
# 7549   Slovak Republic  Social support           Average  2018  89.883419
# 7863             Spain  Social support           Average  2018  90.471734
# 8211            Sweden  Social support           Average  2018  92.755168
# 8536       Switzerland  Social support           Average  2018  92.053340
# 8802           Türkiye  Social support           Average  2018  84.067905
# 9103    United Kingdom  Social support           Average  2018  92.433786
# 9434     United States  Social support           Average  2018  90.352401
# 9831             Chile  Social support           Average  2018  88.750436
# 10039         Colombia  Social support           Average  2018  86.589727
# 10475          Estonia  Social support           Average  2018  91.216496
# 10758           Israel  Social support           Average  2018  89.148464
# 11059           Latvia  Social support           Average  2018  88.151407
# 11361        Lithuania  Social support           Average  2018  86.102505
# 11829         Slovenia  Social support           Average  2018  93.884519
# 12910           Brazil  Social support           Average  2018  87.234402
# 13393           Russia  Social support           Average  2018  88.829803
# 13409       Costa Rica  Social support           Average  2018  86.899136
# 13517     South Africa  Social support           Average  2018  84.094279
#
# ===========================================================
#
#
# GDP
#
#
# ===========================================================
#
#             Country  Happiness Measurement Income Measurement
# 0         Australia              93.282543              1.911
# 1           Austria              90.564838              2.122
# 2           Belgium              92.107227              2.313
# 3            Canada              91.733480              2.268
# 4           Denmark              95.667063              0.709
# 5           Finland              95.927086              1.169
# 6            France              91.375633              2.098
# 7           Germany              90.824276              1.935
# 8            Greece              78.953671              0.774
# 9           Hungary              93.508243              2.839
# 10          Ireland              93.611828              0.708
# 11            Italy              90.675076              1.243
# 12            Japan              87.757218              0.989
# 13            Korea              78.874962              1.476
# 14       Luxembourg              88.977817               2.02
# 15           Mexico              85.724824              4.897
# 16      Netherlands              93.850994              1.601
# 17      New Zealand              95.229375              1.598
# 18           Norway              96.569664              2.765
# 19           Poland              83.764614              1.766
# 20         Portugal              88.469596              1.168
# 21  Slovak Republic              89.883419               2.53
# 22            Spain              90.471734              1.736
# 23           Sweden              92.755168              2.037
# 24      Switzerland              92.053340              0.935
# 25          Türkiye              84.067905             16.332
# 26   United Kingdom              92.433786              2.478
# 27    United States              90.352401              2.439
# 28            Chile              88.750436              2.317
# 29         Colombia              86.589727              3.239
# 30          Estonia              91.216496              3.412
# 31           Israel              89.148464              0.807
# 32           Latvia              88.151407              2.554
# 33        Lithuania              86.102505              2.531
# 34         Slovenia              93.884519              1.737
# 35           Brazil              87.234402              3.665
# 36           Russia              88.829803              2.878
# 37       Costa Rica              86.899136              2.221
# 38     South Africa              84.094279              4.612
# HBox(children=(Output(), Output()))
